# %%
import sys
count = 0
board = [
        [" 1","  2","  3","  4","  5","  6","  7"],
        ["|_|","|_|","|_|","|_|","|_|","|_|","|_|"],
        ["|_|","|_|","|_|","|_|","|_|","|_|","|_|"],
        ["|_|","|_|","|_|","|_|","|_|","|_|","|_|"],
        ["|_|","|_|","|_|","|_|","|_|","|_|","|_|"],
        ["|_|","|_|","|_|","|_|","|_|","|_|","|_|"],
        ["|_|","|_|","|_|","|_|","|_|","|_|","|_|"]
]
def printBoard():
    rows = 7
    cols = 7
    for i in range(rows):
        for j in range(cols):
            print(board[i][j], end=" ")
        print()

def lowestRow(columnChosen):
    col_index = columnChosen - 1 
    for row in range(6, 0, -1):  
        if board[row][col_index] == "|_|":
            return row
    return -1

def checkWinner(row, column):
    playerToken = board[row][column]
    arrayCounter = []
  


    return 0

playing = True

def countMatches(row, col, deltaRow, deltaCol):
    count = 0
    r = row + deltaRow
    c = col + deltaCol

    while inBounds(r,c)



while playing:
    printBoard()
    choice = int(input("Which column are you choosing to drop?"))
    if choice < 1 or choice > 7:
        print("Choose from 1-7")
    elif choice == 0:
        sys.exit("thank you for playing")
        break
    else:
        row = lowestRow(choice)
        col = choice - 1
        if count % 2 == 0:
            board[row][col] = "|X|"
        elif count % 2 == 1:
            board[row][col] = "|O|"    

    
    count += 1
